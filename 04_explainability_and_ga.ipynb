# %% [markdown]
# # 04 Explainability and Genetic Algorithm

# %%
# !pip install -q shap captum

# %%
import shap
import random

# %%
mutation_prompts = [

    "Rewrite with irregular sentence rhythm.",

    "Introduce one subtle grammatical inconsistency.",

    "Use more punctuation variation.",

    "Introduce one archaic adjective naturally."
]

print(mutation_prompts)

# %%
def fitness(human_probability):

    return human_probability

# %%
population = [

    "AI generated paragraph 1",

    "AI generated paragraph 2",

    "AI generated paragraph 3"
]

scores = [random.random() for _ in population]

for p, s in zip(population, scores):

    print(p, s)

# %%
best = sorted(

    zip(population, scores),

    key=lambda x: x[1],

    reverse=True
)

print(best[:2])

# %%
print("GA Attack Pipeline Complete")
