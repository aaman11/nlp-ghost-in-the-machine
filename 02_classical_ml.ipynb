# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from classical_models import train_classical_models

df = pd.read_csv("data/human_stylometry.csv")
feature_cols = ["ttr","hapax","adj_noun_ratio","dep_depth","fkg","word_count","char_count","semicolon","emdash","exclamation","colon","comma"]

rf, xgb, results, X_test, y_test, rf_pred, xgb_pred = train_classical_models(
    df,
    feature_cols=feature_cols,
    label_col="author"
)

print(results["rf_accuracy"], results["xgb_accuracy"])
